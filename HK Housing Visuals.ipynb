# %%
#Prerequisites
import pandas as panda

#Import data from HKMA
capitalMarketsDataFeed = panda.read_json("hkma_data/capitalmarkets_stats.json") 

capitalMarketsDataFeed['result']['records']

#panda.DataFrame(capitalMarketsDataFeed['result']['records'])
# Out:
# [{'end_of_month': '2020-07',
#   'hkd_drmkt_outstand_efbn': 1067849,
#   'hkd_drmkt_outstand_odrinst': None,
#   'hkd_drmkt_outstand_total': None,
#   'hkd_drmkt_new_non_efbn': None,
#   'eq_mkt_hs_index': 24595.35,
#   'eq_mkt_ttl_stock_cap': 40353794.107656,
#   'eq_mkt_fund_raised': 75753.10933},
#  {'end_of_month': '2020-06',
#   'hkd_drmkt_outstand_efbn': 1067705,
#   'hkd_drmkt_outstand_odrinst': 1111327.27406101,
#   'hkd_drmkt_outstand_total': 2179032.27406101,
#   'hkd_drmkt_new_non_efbn': 234508.053639,
#   'eq_mkt_hs_index': 24427.19,
#   'eq_mkt_ttl_stock_cap': 37905667.147791,
#   'eq_mkt_fund_raised': 93698.342849},
#  {'end_of_month': '2020-05',
#   'hkd_drmkt_outstand_efbn': 1067326,
#   'hkd_drmkt_outstand_odrinst': None,
#   'hkd_drmkt_outstand_total': None,
#   'hkd_drmkt_new_non_efbn': None,
#   'eq_mkt_hs_index': 22961.47,
#   'eq_mkt_ttl_stock_cap': 33984729.516599,
#   'eq_mkt_fund_raised': 21707.853655},
#  {'end_of_month': '2020-04',
# ...
